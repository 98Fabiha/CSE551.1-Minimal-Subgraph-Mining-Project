# %%
import pandas as pd

# %%
from google.colab import files

# %%
uploaded = files.upload()
dataset1 = pd.read_csv('panda_LAML.csv',index_col=0)
# Out:
#      <input type="file" id="files-24f76a3b-eac4-49f5-8fba-1a1c148484b8" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-24f76a3b-eac4-49f5-8fba-1a1c148484b8">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
print(dataset1.head())
# Out:
#       ENSG00000000003  ENSG00000000005  ENSG00000000419  ENSG00000000457  \
# AHR         -0.545167        -0.723766        -1.094654        -1.249355
# AIRE        -0.056072         0.255330         0.636908         5.377606
# ALX1         0.192836         0.396289         1.001892         1.710922
# ALX3        -0.058538         0.519708         1.152625         1.814727
# ALX4        -0.114151         0.496872         1.092855         1.671728
#
#       ENSG00000000460  ENSG00000000938  ENSG00000000971  ENSG00000001036  \
# AHR         -1.085477         0.180912        -1.160077        -0.498430
# AIRE         1.534348        -1.437572         0.396404        -0.558479
# ALX1         1.493243        -1.354036         4.035022        -0.433730
# ALX3         1.700155        -1.570280         4.099949        -0.249876
# ALX4         1.594020        -1.489652         4.174561        -0.277895
#
#       ENSG00000001084  ENSG00000001167  ...  ENSG00000273473  ENSG00000273474  \
# ...

# %%
from google.colab import files

# %%
uploaded = files.upload()
dataset2= pd.read_csv('panda_ACC.csv',index_col=0)
# Out:
#      <input type="file" id="files-80255f99-dc45-488c-ad0c-bd1d944b1871" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-80255f99-dc45-488c-ad0c-bd1d944b1871">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
print(dataset2.head())
# Out:
#       ENSG00000000003  ENSG00000000005  ENSG00000000419  ENSG00000000457  \
# AHR         -0.792568        -0.432183        -0.665372        -0.720966
# AIRE         0.036260        -0.409670        -0.008849         4.043188
# ALX1         0.168483        -0.168003         0.183804         0.468686
# ALX3         0.275074        -0.264961         0.134051         0.371216
# ALX4         0.173875        -0.265062         0.122008         0.284398
#
#       ENSG00000000460  ENSG00000000938  ENSG00000000971  ENSG00000001036  \
# AHR         -0.495510        -0.554395        -1.024086        -0.440877
# AIRE        -0.142401        -0.305043         0.022437        -0.622903
# ALX1         0.041988        -0.271278         3.690817        -0.371714
# ALX3        -0.033110        -0.303631         3.718314        -0.457229
# ALX4         0.003294        -0.340181         3.771594        -0.492705
#
#       ENSG00000001084  ENSG00000001167  ...  ENSG00000273473  ENSG00000273474  \
# ...

# %%
from google.colab import files

# %%
uploaded = files.upload()
dataset3= pd.read_csv('panda_BLCA.csv',index_col=0)
# Out:
#      <input type="file" id="files-aeef05db-6af8-42b5-8a7a-ffd1b3dd28ee" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-aeef05db-6af8-42b5-8a7a-ffd1b3dd28ee">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
print(dataset3.head())
# Out:
#       ENSG00000000003  ENSG00000000005  ENSG00000000419  ENSG00000000457  \
# AHR         -0.473695        -0.617424        -0.716935        -0.883365
# AIRE        -0.276002        -0.005395        -0.351535         4.637900
# ALX1        -0.153480         0.276919        -0.146036         0.893158
# ALX3        -0.216951         0.203521        -0.111570         0.971243
# ALX4        -0.343550         0.178665        -0.148088         0.884700
#
#       ENSG00000000460  ENSG00000000938  ENSG00000000971  ENSG00000001036  \
# AHR         -0.974099        -0.006468        -0.976061        -0.235438
# AIRE         0.720381        -1.111580         0.454468        -1.338518
# ALX1         0.941240        -1.165250         4.089457        -1.186877
# ALX3         1.076505        -1.247193         4.122651        -1.283893
# ALX4         1.031672        -1.224652         4.223675        -1.309530
#
#       ENSG00000001084  ENSG00000001167  ...  ENSG00000273473  ENSG00000273474  \
# ...

# %%
import pandas as pd

# %%
merged_dataset = pd.merge(dataset1, dataset2, left_index=True, right_index=True, how='outer')
merged_dataset = pd.merge(merged_dataset, dataset3, left_index=True, right_index=True, how='outer')

# %%
new_binary_dataset = (merged_dataset > 0).astype(int)

# %%
new_binary_dataset = new_binary_dataset.fillna(0)

# %%
new_binary_dataset.to_csv('new_binary_dataset.csv',index = True)

# %%
print(new_binary_dataset.head())
# Out:
#       ENSG00000000003_x  ENSG00000000005_x  ENSG00000000419_x  \
# AHR                   0                  0                  0
# AIRE                  0                  1                  1
# ALX1                  1                  1                  1
# ALX3                  0                  1                  1
# ALX4                  0                  1                  1
#
#       ENSG00000000457_x  ENSG00000000460_x  ENSG00000000938_x  \
# AHR                   0                  0                  1
# AIRE                  1                  1                  0
# ALX1                  1                  1                  0
# ALX3                  1                  1                  0
# ALX4                  1                  1                  0
#
#       ENSG00000000971_x  ENSG00000001036_x  ENSG00000001084_x  \
# AHR                   0                  0                  0
# AIRE                  1                  0                  1
# ...

# %%
from google.colab import files
files.download('new_binary_dataset.csv')
